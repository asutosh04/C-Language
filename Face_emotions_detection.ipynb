# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwanthb51/codeclause_faceemotions_detection/blob/main/Face_emotions_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deepface
# Out:
# ...
#   Using cached deepface-0.0.79-py3-none-any.whl (49 kB)
# ...
#   Using cached gdown-4.7.1-py3-none-any.whl (15 kB)
# ...
#   Using cached mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
# ...
#   Using cached retina_face-0.0.13-py3-none-any.whl (16 kB)
# ...
#   Using cached fire-0.5.0.tar.gz (88 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached gunicorn-20.1.0-py3-none-any.whl (79 kB)
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116963 sha256=b868faec75d3fe3ddd77826c4e99e5fd7c64a56c2e6ab2864db2b48915abbc4e
#   Stored in directory: c:\users\kiit\appdata\local\pip\cache\wheels\90\d4\f7\9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

import matplotlib.pyplot as plt

from deepface import DeepFace
# Out:
# Directory  C:\Users\KIIT /.deepface created
# Directory  C:\Users\KIIT /.deepface/weights created

# %%
img = cv2.imread('profile-img.jpg')

  

# call imshow() using plt object

plt.imshow(img[:, :, : : -1])

  

# display that image

plt.show()

# %%
result = DeepFace.analyze(img,

                          actions = ['emotion'])

  

# print result

print(result)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\KIIT\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:01<00:00, 3.38MB/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# [{'emotion': {'angry': 1.765769147342732e-05, 'disgust': 1.6243392322379795e-08, 'fear': 2.7776612178393457e-05, 'happy': 1.32097050970617, 'sad': 0.18888357988423585, 'surprise': 1.2086045596398511e-05, 'neutral': 98.49008908808763}, 'dominant_emotion': 'neutral', 'region': {'x': 663, 'y': 492, 'w': 693, 'h': 693}}]

# %%
import cv2

import matplotlib.pyplot as plt

from deepface import DeepFace

  

# read image

img = cv2.imread('profile-img.jpg')

  

# call imshow() using plt object

plt.imshow(img[:,:,::-1])

  

# display that image

plt.show()

  

# storing the result

result = DeepFace.analyze(img,actions=['emotion'])

  

# print result

print(result)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.25it/s]
# [{'emotion': {'angry': 1.765769147342732e-05, 'disgust': 1.6243392322379795e-08, 'fear': 2.7776612178393457e-05, 'happy': 1.32097050970617, 'sad': 0.18888357988423585, 'surprise': 1.2086045596398511e-05, 'neutral': 98.49008908808763}, 'dominant_emotion': 'neutral', 'region': {'x': 663, 'y': 492, 'w': 693, 'h': 693}}]
